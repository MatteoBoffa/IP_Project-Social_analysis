# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import sklearn.cluster as clus
import time 
from scipy.spatial.distance import cdist
from sklearn.metrics import silhouette_samples, silhouette_score
from pyproj import Transformer
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# ## Import data

# %%
PATH_TO_ANALYSE="./Raw_data/points_global.csv"
base_dataFrame=pd.read_csv(PATH_TO_ANALYSE)
base_dataFrame=base_dataFrame.drop(["Unnamed: 0"],axis=1)

# %% [markdown]
# ## Convert data to x-y coordinates

# %%
transformer = Transformer.from_crs("epsg:4326", "epsg:3003")
for i in range(0,len(base_dataFrame)):
    x,y=transformer.transform(base_dataFrame.iloc[i][1],base_dataFrame.iloc[i][0])
    base_dataFrame.iloc[i][1]=x
    base_dataFrame.iloc[i][0]=y

# %% [markdown]
# ## Plot with outliers

# %%
plt.plot(base_dataFrame["lat"], base_dataFrame["lon"], 'o', markerfacecolor="green", markeredgecolor='k', markersize=8)
plt.title("Map with outliers")
# Out:
# Text(0.5, 1.0, 'Map with outliers')

# %% [markdown]
# ## Sort data and standardize

# %%
base_dataFrame_scaled = base_dataFrame.sort_values(by=['lat','lon'])
base_dataFrame_scaled = StandardScaler().fit_transform(base_dataFrame)

# %% [markdown]
# ## Find a range of variation for epsilon (spannometric)

# %%
df2= pd.DataFrame(columns = ["index","distance"])
for i in range(0,len(base_dataFrame)-1):
    dist=np.linalg.norm(base_dataFrame_scaled[i]-base_dataFrame_scaled[i+1])
    df2 = df2.append({"index":str(i),"distance":dist}, ignore_index=True)

# %% [markdown]
# ## Plot the elbow
# #### (n.b. the idea is considerig the elbow's values as good values for epsilon)

# %%
df2=df2.sort_values(by=['distance'])
plt.scatter(df2["index"],df2["distance"])
plt.title("Distances among points")
# Out:
# Text(0.5, 1.0, 'Distances among points')

# %% [markdown]
# # DB-Scan method's tuning

# %% [markdown]
# #### Values that will be tested:

# %%
e_t=np.arange(0.75,2,0.25)
M_t=np.arange(20,60,5)

# %% [markdown]
# #### Collectors of results:

# %%
list_of_parameters=[]

# %%
for e in e_t:
    for M in M_t:
        db_clusters=clus.DBSCAN(eps=e, min_samples=M).fit(base_dataFrame_scaled)
        lab=db_clusters.labels_
        
        #These are parameters which will be usefull later on
        core_samples_mask = np.zeros_like(lab, dtype=bool)
        core_samples_mask[db_clusters.core_sample_indices_] = True
        params={
            "silhouette":silhouette_score(base_dataFrame,lab),
            "e":e,
            "M":M,
            "labels":lab
        }
        silhouettes.append(silhouette_score(base_dataFrame,lab))
        params.append((e,M,lab))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-16-a4facb98a573> in <module>
#       7         core_samples_mask = np.zeros_like(lab, dtype=bool)
#       8         core_samples_mask[db_clusters.core_sample_indices_] = True
# ----> 9         silhouettes.append(silhouette_score(base_dataFrame,lab))
#      10         params.append((e,M,lab))
#
# ~/.local/lib/python3.8/site-packages/sklearn/utils/validation.py in inner_f(*args, **kwargs)
#      70                           FutureWarning)
#      71         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 72         return f(**kwargs)
#      73     return inner_f
#      74
#
# ~/.local/lib/python3.8/site-packages/sklearn/metrics/cluster/_unsupervised.py in silhouette_score(X, labels, metric, sample_size, random_state, **kwds)
#     115         else:
#     116             X, labels = X[indices], labels[indices]
# --> 117     return np.mean(silhouette_samples(X, labels, metric=metric, **kwds))
#     118
#     119
#
# ~/.local/lib/python3.8/site-packages/sklearn/utils/validation.py in inner_f(*args, **kwargs)
#      70                           FutureWarning)
#      71         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 72         return f(**kwargs)
#      73     return inner_f
#      74
#
# ~/.local/lib/python3.8/site-packages/sklearn/metrics/cluster/_unsupervised.py in silhouette_samples(X, labels, metric, **kwds)
#     232     reduce_func = functools.partial(_silhouette_reduce,
#     233                                     labels=labels, label_freqs=label_freqs)
# --> 234     results = zip(*pairwise_distances_chunked(X, reduce_func=reduce_func,
#     235                                               **kwds))
#     236     intra_clust_dists, inter_clust_dists = results
#
# ~/.local/lib/python3.8/site-packages/sklearn/metrics/pairwise.py in pairwise_distances_chunked(X, Y, reduce_func, metric, n_jobs, working_memory, **kwds)
#    1614         else:
#    1615             X_chunk = X[sl]
# -> 1616         D_chunk = pairwise_distances(X_chunk, Y, metric=metric,
#    1617                                      n_jobs=n_jobs, **kwds)
#    1618         if ((X is Y or Y is None)
#
# ~/.local/lib/python3.8/site-packages/sklearn/utils/validation.py in inner_f(*args, **kwargs)
#      70                           FutureWarning)
#      71         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 72         return f(**kwargs)
#      73     return inner_f
#      74
#
# ~/.local/lib/python3.8/site-packages/sklearn/metrics/pairwise.py in pairwise_distances(X, Y, metric, n_jobs, force_all_finite, **kwds)
#    1777         func = partial(distance.cdist, metric=metric, **kwds)
#    1778
# -> 1779     return _parallel_pairwise(X, Y, func, n_jobs, **kwds)
#    1780
#    1781
#
# ~/.local/lib/python3.8/site-packages/sklearn/metrics/pairwise.py in _parallel_pairwise(X, Y, func, n_jobs, **kwds)
#    1358
#    1359     if effective_n_jobs(n_jobs) == 1:
# -> 1360         return func(X, Y, **kwds)
#    1361
#    1362     # enforce a threading backend to prevent data communication overhead
#
# ~/.local/lib/python3.8/site-packages/sklearn/utils/validation.py in inner_f(*args, **kwargs)
#      70                           FutureWarning)
#      71         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 72         return f(**kwargs)
#      73     return inner_f
#      74
#
# ~/.local/lib/python3.8/site-packages/sklearn/metrics/pairwise.py in euclidean_distances(X, Y, Y_norm_squared, squared, X_norm_squared)
#     308     else:
#     309         # if dtype is already float64, no need to chunk and upcast
# --> 310         distances = - 2 * safe_sparse_dot(X, Y.T, dense_output=True)
#     311         distances += XX
#     312         distances += YY
#
# ~/.local/lib/python3.8/site-packages/sklearn/utils/validation.py in inner_f(*args, **kwargs)
#      70                           FutureWarning)
#      71         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 72         return f(**kwargs)
#      73     return inner_f
#      74
#
# ~/.local/lib/python3.8/site-packages/sklearn/utils/extmath.py in safe_sparse_dot(a, b, dense_output)
#     151             ret = np.dot(a, b)
#     152     else:
# --> 153         ret = a @ b
#     154
#     155     if (sparse.issparse(a) and sparse.issparse(b)
#
# KeyboardInterrupt:

# %%
for it 

n_clusters_ = len(set(lab)) - (1 if -1 in lab else 0)
n_noise_ = list(lab).count(-1)
print("\nResult with e="+str(e)+" and M="+str(M)+":") 
print(f"\tAverage silhouette: {silhouette_avg}\n\tN° of clusters: {len(set(lab))}\n\tNumber of outliers: {list(lab).count(-1)}")
